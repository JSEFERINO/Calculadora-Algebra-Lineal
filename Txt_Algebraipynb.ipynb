# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Calculadora-Algebra-Lineal/blob/main/Txt_Algebraipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# SCRIPT COMPLETO - SUBIR TODO A GITHUB
# ============================================================

import os
import subprocess

print("="*60)
print("📤 PREPARANDO ARCHIVOS PARA ÁLGEBRA LINEAL")
print("="*60)

# 1. Verificar que app.py existe
if not os.path.exists('app.py'):
    print("❌ app.py NO encontrado")
    print("📌 Asegúrate de tener el archivo app.py")
else:
    print("✅ app.py encontrado")

# 2. Crear requirements.txt
with open('requirements.txt', 'w') as f:
    f.write('''streamlit>=1.28.0
numpy>=1.24.0
pandas>=2.0.0
plotly>=5.17.0
scipy>=1.10.0
matplotlib>=3.7.0
seaborn>=0.12.0
''')
print("✅ requirements.txt creado")

# 3. Crear packages.txt
with open('packages.txt', 'w') as f:
    f.write('''build-essential
python3-dev
''')
print("✅ packages.txt creado")

# 4. Mostrar archivos
print("\n📋 Archivos en el directorio:")
for file in ['app.py', 'requirements.txt', 'packages.txt']:
    if os.path.exists(file):
        size = os.path.getsize(file)
        print(f"  ✅ {file} ({size} bytes)")
    else:
        print(f"  ❌ {file} (no encontrado)")

# 5. Instrucciones
print("\n" + "="*60)
print("📤 INSTRUCCIONES PARA SUBIR A GITHUB:")
print("="*60)
print("""
1. Ve a: https://github.com/JSEFERINO/Calculadora-Algebra-Lineal
2. Haz clic en 'Add file' → 'Upload files'
3. Selecciona los archivos:
   ✅ app.py
   ✅ requirements.txt
   ✅ packages.txt
4. Escribe un mensaje: "Añadido requirements.txt"
5. Haz clic en 'Commit changes'

6. Luego ve a: https://share.streamlit.io/
7. Selecciona tu app 'Calculadora-Algebra-Lineal'
8. Haz clic en 'Redeploy' o 'Rebuild'
9. Espera 2-3 minutos
10. ¡Listo! 🎉
""")

print("="*60)
print("🌐 URL de tu app:")
print("https://jseferino-calculadora-algebra-lineal-app-nbsvjp.streamlit.app//")
print("="*60)
# Out:
# ...
# 📤 PREPARANDO ARCHIVOS PARA ÁLGEBRA LINEAL
# ...
# ❌ app.py NO encontrado
# 📌 Asegúrate de tener el archivo app.py
# ✅ requirements.txt creado
# ✅ packages.txt creado
#
# 📋 Archivos en el directorio:
#   ❌ app.py (no encontrado)
#   ✅ requirements.txt (109 bytes)
#   ✅ packages.txt (28 bytes)
#
# ...
# 📤 INSTRUCCIONES PARA SUBIR A GITHUB:
# ...
#
# 1. Ve a: https://github.com/JSEFERINO/Calculadora-Algebra-Lineal
# 2. Haz clic en 'Add file' → 'Upload files'
# 3. Selecciona los archivos:
#    ✅ app.py
#    ✅ requirements.txt
#    ✅ packages.txt
# 4. Escribe un mensaje: "Añadido requirements.txt"
# 5. Haz clic en 'Commit changes'
#
# 6. Luego ve a: https://share.streamlit.io/
# 7. Selecciona tu app 'Calculadora-Algebra-Lineal'
# 8. Haz clic en 'Redeploy' o 'Rebuild'
# 9. Espera 2-3 minutos
# 10. ¡Listo! 🎉
#
# ...
# 🌐 URL de tu app:
# https://jseferino-calculadora-algebra-lineal-app-nbsvjp.streamlit.app//
# ...
