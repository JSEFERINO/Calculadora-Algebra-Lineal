# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Calculadora-Algebra-Lineal/blob/main/Txt_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# SUBIR A GITHUB DESDE COLAB
# ============================================================

# 1. Instalar git
# !apt-get install git -q

# 2. Configurar git (reemplaza con tus datos)
# !git config --global user.email "juliohur@gmail.com.com"
# !git config --global user.name "Maestro Seferino"

# 3. Clonar tu repositorio (reemplaza con tu URL)
# !git clone https://github.com/JSEFERINO/Calculadora-Algebra-Lineal.git
# %cd Calculadora-Algebra-Lineal

# 4. Copiar archivos
# !cp ../app.py .
# !cp ../requirements.txt .

# 5. Subir a GitHub
# !git add .
# !git commit -m "Añadiendo calculadora de Calculadora Algebra Lineal"
# !git push origin main

print("✅ Archivos subidos a GitHub")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# Cloning into 'Calculadora-Algebra-Lineal'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 7.42 KiB | 7.42 MiB/s, done.
# /content/Calculadora-Algebra-Lineal
# cp: cannot stat '../app.py': No such file or directory
# cp: cannot stat '../requirements.txt': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ Archivos subidos a GitHub
